# %%
# 정수형
a = 123
b = -178
c = 0
print(a)
print(b)
print(c)
type(a)

# %%
# 실수형

a = 1.2
b = -3.45
print(a)

# %%
# 8진수와 16진수
a = 0o123
print(a)
b= 0x111

print(b)
1 * 8
# Out:
# 83
# 273
# 8

# %%
a = 3
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
# x의 y제곱을 나타내는 ** 연산자
a = 3
b = 4
a ** b
# Out:
# 81

# %%
#나눗셈 후 나머지를 구하는 % 연산자
print(7 % 3)
print(3 % 2)
# Out:
# 1
# 1

# %%
# 나눗셈 후 몫을 구하는 연산자
print(7 // 4)
# Out:
# 1

# %%
# 복합연산자
a = 1
a += 1
# a = a+1
# +=
# -=
# *+
# /=

print(a)
# Out:
# 2
